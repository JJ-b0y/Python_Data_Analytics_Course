# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt  
import ast

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# Further Cleanup: job_Skills to list datatype
df['job_skills'] = df['job_skills'].apply(lambda y: ast.literal_eval(y) if pd.notna(y) else y)

# Filtering for Data Analyst Jobs
df_DA = df[df['job_title_short'] == 'Data Analyst'].copy()

# %%
df_DA['job_posted_month_no'] = df_DA['job_posted_date'].dt.month
# Out:
# "df_DA_explode = df_DA.explode('job_skills')\ndf_DA_exploded = df_DA_explode.to_frame()\ndf_DA_exploded.pivot_table(index='job_posted_month_no',\n                          columns='job_skills',\n                          aggfunc='size',\n                          fill_value=0)\ndf_DA_pivot.loc['Total'] = df_DA_pivot.sum()\ndf_DA_pivot.loc['Total'].sort_values(ascending=False)\ndf_DA_pivot = df_DA_pivot[df_DA_pivot.loc['Total'].sort_values(ascending=False).index]\ndf_DA_pivot = df_DA_pivot.drop('Total')\n\nrange = 5\n\ndf_DA_pivot.iloc[:, :range].plot(kind='line')\nplt.title(f'Top {range} Skills for Data Analysts per Month')\nplt.xlabel('Month Number')\nplt.ylabel('Skill Count')\nplt.show()"

# %%
df_DA
# Out:
#        job_title_short                                          job_title  \
# 1         Data Analyst                                       Data Analyst
# 12        Data Analyst        Stagiaire Data Analyst (H/F) - Lyon (69006)
# 18        Data Analyst                                       Data Analyst
# 31        Data Analyst                           Stage - Data Analyst F/H
# 34        Data Analyst  Data Analyst als Marketing Manager Automation ...
# ...                ...                                                ...
# 785703    Data Analyst            Data Analyst - CRYPTOGRAPHY - Full-time
# 785705    Data Analyst          Expert Business Data Analyst - Now Hiring
# 785715    Data Analyst  Amul Careers 2023 - Apply Online - Data Analys...
# 785717    Data Analyst                 Data & Analytics Architect (w/m/x)
# 785737    Data Analyst                                   CRM Data Analyst
#
#                         job_location  \
# 1       Guadalajara, Jalisco, Mexico
# ...

# %%
df_DA.explode('job_skills')
# Out:
#        job_title_short                           job_title  \
# 1         Data Analyst                        Data Analyst
# 1         Data Analyst                        Data Analyst
# 1         Data Analyst                        Data Analyst
# 1         Data Analyst                        Data Analyst
# 1         Data Analyst                        Data Analyst
# ...                ...                                 ...
# 785717    Data Analyst  Data & Analytics Architect (w/m/x)
# 785737    Data Analyst                    CRM Data Analyst
# 785737    Data Analyst                    CRM Data Analyst
# 785737    Data Analyst                    CRM Data Analyst
# 785737    Data Analyst                    CRM Data Analyst
#
#                         job_location                    job_via  \
# 1       Guadalajara, Jalisco, Mexico           via BeBee México
# 1       Guadalajara, Jalisco, Mexico           via BeBee México
# ...

# %%
df_DA_exploded = df_DA.explode('job_skills')

# %%
df_DA_exploded
# Out:
#        job_title_short                           job_title  \
# 1         Data Analyst                        Data Analyst
# 1         Data Analyst                        Data Analyst
# 1         Data Analyst                        Data Analyst
# 1         Data Analyst                        Data Analyst
# 1         Data Analyst                        Data Analyst
# ...                ...                                 ...
# 785717    Data Analyst  Data & Analytics Architect (w/m/x)
# 785737    Data Analyst                    CRM Data Analyst
# 785737    Data Analyst                    CRM Data Analyst
# 785737    Data Analyst                    CRM Data Analyst
# 785737    Data Analyst                    CRM Data Analyst
#
#                         job_location                    job_via  \
# 1       Guadalajara, Jalisco, Mexico           via BeBee México
# 1       Guadalajara, Jalisco, Mexico           via BeBee México
# ...

# %%
df_DA_exploded.pivot_table(index='job_posted_month_no',
                          columns='job_skills',
                          aggfunc='size',
                          fill_value=0)
# Out:
# job_skills           airflow  airtable  alteryx  angular  angular.js  ansible  \
# job_posted_month_no
# 1                        197        17      551       63           2       20
# 2                        169         2      448       49           0       14
# 3                        181         4      442       34           0       23
# 4                        155         4      413       22           0       11
# 5                        128         8      310       30           0       19
# 6                        164        14      393       29           0       14
# 7                        207         4      366       15           0        8
# 8                        197         3      413       21           0       12
# 9                        118         4      317       21           0       14
# 10                       173        11      350       40           0       19
# 11                       169         7      293       24           0       19
# ...

# %%
df_DA_pivot = df_DA_exploded.pivot_table(index='job_posted_month_no',
                          columns='job_skills',
                          aggfunc='size',
                          fill_value=0)

# %%
df_DA_pivot.loc['Total'] = df_DA_pivot.sum()

# %%
df_DA_pivot.loc['Total'].sort_values(ascending=False)
# Out:
# job_skills
# sql          92428
# excel        66860
# python       57190
# tableau      46455
# power bi     39380
#              ...
# esquisse         1
# suse             1
# capacitor        1
# chainer          1
# msaccess         1
# Name: Total, Length: 235, dtype: int64

# %%
df_DA_pivot[df_DA_pivot.loc['Total'].sort_values(ascending=False).index]
# Out:
# job_skills             sql  excel  python  tableau  power bi      r    sas  \
# job_posted_month_no
# 1                    11336   8170    6606     5596      4285   3607   3830
# 2                     7947   5772    4751     3936      3307   2576   2634
# 3                     7868   5675    4741     4051      3176   2650   2554
# 4                     7553   5496    4557     3776      3106   2399   2598
# 5                     6617   4773    4070     3245      2695   2093   1940
# 6                     7584   5724    4707     3812      3275   2442   2174
# 7                     7687   5513    4831     3928      3350   2444   2118
# 8                     8823   6482    5576     4533      3859   2975   2560
# 9                     6829   4886    4229     3446      3118   2146   1880
# 10                    7474   5217    4693     3709      3340   2380   2114
# 11                    6652   4776    4233     3284      3012   2159   1738
# ...

# %%
df_DA_pivot = df_DA_pivot[df_DA_pivot.loc['Total'].sort_values(ascending=False).index]

# %%
df_DA_pivot = df_DA_pivot.drop('Total')

# %% [markdown]
# # **Having already done this in our explode() exercise, let's customize the plot further**

# %%
range = 5

df_DA_pivot.iloc[:, :range].plot(
                                kind='line',
                                linewidth=4,
                                linestyle=':',      # Other Options: '-', ':', '-.'
                                colormap='viridis', # Other Options: 'plasma', 'inferno', 'magma', 'cividis' visit matplotlib.org/cheatsheets for more 
                                marker='+',         # Other Options: 'x', '+', '*', 's', ',', '.', '1', '2', '3', ...
                                markersize=15,
                                figsize=(10,5)
                                )
plt.title(f'Top {range} Skills for Data Analysts per Month')
plt.xlabel('Month Number')
plt.ylabel('Skill Count')
plt.show()

# %% [markdown]
# # **Customizing the Scatter Plot from last Exercise**

# %%
df_exploded = df.explode('job_skills').copy()

df_DA_exploded
# Out:
#        job_title_short                           job_title  \
# 1         Data Analyst                        Data Analyst
# 1         Data Analyst                        Data Analyst
# 1         Data Analyst                        Data Analyst
# 1         Data Analyst                        Data Analyst
# 1         Data Analyst                        Data Analyst
# ...                ...                                 ...
# 785717    Data Analyst  Data & Analytics Architect (w/m/x)
# 785737    Data Analyst                    CRM Data Analyst
# 785737    Data Analyst                    CRM Data Analyst
# 785737    Data Analyst                    CRM Data Analyst
# 785737    Data Analyst                    CRM Data Analyst
#
#                         job_location                    job_via  \
# 1       Guadalajara, Jalisco, Mexico           via BeBee México
# 1       Guadalajara, Jalisco, Mexico           via BeBee México
# ...

# %%
skill_stats = df_exploded.groupby('job_skills').agg(
                                                    median_salary=(
                                                                    'salary_year_avg',
                                                                    'median'
                                                                    ),
                                                    skill_count=('job_skills',
                                                                 'count'
                                                                 )
)

skill_count = 20
skill_stats = skill_stats.sort_values(by='skill_count', ascending=False).head(skill_count)

skill_stats
# Out:
#             median_salary  skill_count
# job_skills
# sql              120000.0       384849
# python           125000.0       380909
# aws              135000.0       145381
# azure            125000.0       132527
# r                119550.0       130892
# tableau          111175.0       127213
# excel             92500.0       127018
# spark            140000.0       114609
# power bi         102000.0        98147
# java             134241.0        85612
# sas              110000.0        83404
# hadoop           135000.0        64842
# scala            147500.0        56886
# snowflake        135000.0        55015
# databricks       127500.0        53182
# gcp              133500.0        50727
# git              125000.0        50226
# kafka            147500.0        49926
# airflow          147090.5        45254
# oracle           112500.0        45221

# %%
skill_stats.plot(
                kind='scatter',
                x='skill_count',
                y='median_salary'
                )

for i, txt in enumerate(skill_stats.index):
    plt.text(skill_stats['skill_count'].iloc[i], skill_stats['median_salary'].iloc[i], txt)

plt.title(f'Salary vs. Count of Job Postings for the Top {skill_count} Skills')
plt.xlabel('Count of Job Postings')
plt.ylabel('Median Yearly Salary ($USD)')
plt.tight_layout()
plt.show()

# %% [markdown]
# # **We need to adjust the text label to accomodate more data entry on the scatter plot**

# %%
from adjustText import adjust_text

skill_stats.plot(
                kind='scatter',
                x='skill_count',
                y='median_salary'
                )
texts = []
for i, txt in enumerate(skill_stats.index):
    texts.append(plt.text(skill_stats['skill_count'].iloc[i], skill_stats['median_salary'].iloc[i], txt)) # Into texts as defined in order to adjust

adjust_text(texts, arrowprops=dict(arrowstyle='->', color='gray', lw=1))

ax = plt.gca()
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda y, pos:f'${int(y/1000)}K'))

plt.title(f'Salary vs. Count of Job Postings for the Top {skill_count} Skills')
plt.xlabel('Count of Job Postings')
plt.ylabel('Median Yearly Salary ($USD)')
plt.ylim()
plt.tight_layout()
plt.show()
